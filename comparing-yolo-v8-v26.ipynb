# %%
# !pip install torch==2.4.0+cu118 torchvision==0.19.0+cu118 torchaudio==2.4.0+cu118 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.7/857.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 115.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 104.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 65.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 56.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 102.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 15.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
import random
import shutil
import matplotlib.pyplot as plt
import cv2

# %%
# Load the best versions
model_8_final = YOLO("/kaggle/input/notebooks/subhasishcharan/object-recognision-1/best_8.pt")
model_26_final = YOLO("/kaggle/input/notebooks/subhasishcharan/object-recognision-2/best_26.pt")

# --- 3. RANDOM TEST SELECTION ---
test_path = "/kaggle/input/datasets/sarkisshilgevorkyan/coco-dataset-for-yolo/coco/images/test2017"
all_images = [os.path.join(test_path, f) for f in os.listdir(test_path) if f.endswith(('.jpg', '.png'))]
random_10 = random.sample(all_images, 10)
# --- 4. PREDICT & DISPLAY ---
print("\n--- Displaying Results for 10 Random Images ---")
for img_path in random_10:
    res8 = model_8_final.predict(source=img_path, conf=0.25, save=False)[0]
    res26 = model_26_final.predict(source=img_path, conf=0.25, save=False)[0]
    
     #Create side-by-side plot
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
    
    ax1.imshow(cv2.cvtColor(res8.plot(), cv2.COLOR_BGR2RGB))
    ax1.set_title(f"YOLOv8: {os.path.basename(img_path)}")
    ax1.axis('off')
    
    ax2.imshow(cv2.cvtColor(res26.plot(), cv2.COLOR_BGR2RGB))
    ax2.set_title(f"YOLO26: {os.path.basename(img_path)}")
    ax2.axis('off')
    
    plt.show()
# Out:
# --- Displaying Results for 10 Random Images ---
#
# image 1/1 /kaggle/input/datasets/sarkisshilgevorkyan/coco-dataset-for-yolo/coco/images/test2017/000000444697.jpg: 480x640 2 persons, 2 cars, 1 fire hydrant, 50.2ms
# Speed: 5.3ms preprocess, 50.2ms inference, 20.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/input/datasets/sarkisshilgevorkyan/coco-dataset-for-yolo/coco/images/test2017/000000444697.jpg: 480x640 2 persons, 2 cars, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 /kaggle/input/datasets/sarkisshilgevorkyan/coco-dataset-for-yolo/coco/images/test2017/000000116728.jpg: 448x640 10 persons, 3 baseball bats, 1 baseball glove, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# ...
